# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
x = pd.read_csv('refined_x.csv')
y = pd.read_csv('refined_y.csv')

# %%
x.head()
# Out:
#    Unnamed: 0            timestamp  airpressure     airtemp  \
# 0           0  2015-12-31 00:00:00   84055.0703  274.887909
# 1           1  2015-12-31 03:00:00   84247.2344  277.503204
# 2           2  2015-12-31 06:00:00   84256.8281  288.390137
# 3           3  2015-12-31 09:00:00   84185.4141  288.949371
# 4           4  2015-12-31 12:00:00   84141.4141  277.850464
#
#    specific_humidity  windspeed      time updated_date  hour  min  \
# 0           0.000971   2.769442  00:00:00   12-31-2015     0    0
# 1           0.001098   2.950434  03:00:00   12-31-2015     3    0
# 2           0.001060   1.049703  06:00:00   12-31-2015     6    0
# 3           0.001141   1.993747  09:00:00   12-31-2015     9    0
# 4           0.001479   1.554527  12:00:00   12-31-2015    12    0
#
#   time_updated updated_timestamp
# 0        00:00  12-31-2015 00:00
# 1        03:00  12-31-2015 03:00
# 2        06:00  12-31-2015 06:00
# 3        09:00  12-31-2015 09:00
# 4        12:00  12-31-2015 12:00

# %%
y.head()
# Out:
#    Unnamed: 0         timestamp  avg_rain   time        date updated_timestamp
# 0           0   12/31/2015 0:00       0.0   0:00  12-31-2015   12-31-2015 0:00
# 1           1   12/31/2015 3:00       0.0   3:00  12-31-2015   12-31-2015 3:00
# 2           2   12/31/2015 6:00       0.0   6:00  12-31-2015   12-31-2015 6:00
# 3           3   12/31/2015 9:00       0.0   9:00  12-31-2015   12-31-2015 9:00
# 4           4  12/31/2015 12:00       0.0  12:00  12-31-2015  12-31-2015 12:00

# %%
df = pd.merge(x, y, on='updated_timestamp', how='outer')
df.head()

df.to_csv('full_dataset.csv')

# %%
full_df = pd.read_csv('full_dataset.csv')
full_df
# Out:
#        Unnamed: 0  Unnamed: 0_x          timestamp_x  airpressure     airtemp  \
# 0               0           0.0  2015-12-31 00:00:00   84055.0703  274.887909
# 1               1           1.0  2015-12-31 03:00:00   84247.2344  277.503204
# 2               2           2.0  2015-12-31 06:00:00   84256.8281  288.390137
# 3               3           3.0  2015-12-31 09:00:00   84185.4141  288.949371
# 4               4           4.0  2015-12-31 12:00:00   84141.4141  277.850464
# 5               5           5.0  2015-12-31 15:00:00   84274.5781  277.281494
# 6               6           6.0  2015-12-31 18:00:00   84153.1719  278.319336
# 7               7           7.0  2015-12-31 21:00:00   84088.6875  277.331177
# 8               8           8.0  2016-01-01 00:00:00   84080.2500  276.168121
# 9               9           9.0  2016-01-01 03:00:00   84233.2109  279.759460
# 10             10          10.0  2016-01-01 06:00:00   84268.0391  288.306488
# ...

# %%
#full_df = full_df.drop(['Unnamed: 0','Unnamed: 0_x','timestamp_x','Unnamed: 0_y'],axis=1)
full_df
# Out:
#        airpressure     airtemp  specific_humidity  windspeed  \
# 0       84055.0703  274.887909           0.000971   2.769442
# 1       84247.2344  277.503204           0.001098   2.950434
# 2       84256.8281  288.390137           0.001060   1.049703
# 3       84185.4141  288.949371           0.001141   1.993747
# 4       84141.4141  277.850464           0.001479   1.554527
# 5       84274.5781  277.281494           0.001506   1.675666
# 6       84153.1719  278.319336           0.001504   2.056827
# 7       84088.6875  277.331177           0.001430   1.752135
# 8       84080.2500  276.168121           0.001194   1.352436
# 9       84233.2109  279.759460           0.001747   1.633569
# 10      84268.0391  288.306488           0.001238   1.523540
# 11      84144.5781  288.430725           0.001408   2.178107
# 12      84146.8516  276.618866           0.001835   0.974976
# 13      84298.4531  275.936127           0.001502   1.556562
# ...

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13420 entries, 0 to 13419
# Data columns (total 14 columns):
# airpressure          8776 non-null float64
# airtemp              8776 non-null float64
# specific_humidity    8776 non-null float64
# windspeed            8776 non-null float64
# time_x               8776 non-null object
# updated_date         8776 non-null object
# hour                 8776 non-null float64
# min                  8776 non-null float64
# time_updated         8776 non-null object
# updated_timestamp    13420 non-null object
# timestamp_y          8776 non-null object
# avg_rain             8776 non-null float64
# time_y               8776 non-null object
# date                 8776 non-null object
# dtypes: float64(7), object(7)
# memory usage: 1.4+ MB

# %%
df_inner = pd.merge(x, y, on='updated_timestamp', how='inner')
df_inner.head()

#df.to_csv('full_dataset.csv')
# Out:
#    Unnamed: 0_x          timestamp_x  airpressure     airtemp  \
# 0             4  2015-12-31 12:00:00   84141.4141  277.850464
# 1             5  2015-12-31 15:00:00   84274.5781  277.281494
# 2             6  2015-12-31 18:00:00   84153.1719  278.319336
# 3             7  2015-12-31 21:00:00   84088.6875  277.331177
# 4             8  2016-01-01 00:00:00   84080.2500  276.168121
#
#    specific_humidity  windspeed    time_x updated_date  hour  min  \
# 0           0.001479   1.554527  12:00:00   12-31-2015    12    0
# 1           0.001506   1.675666  15:00:00   12-31-2015    15    0
# 2           0.001504   2.056827  18:00:00   12-31-2015    18    0
# 3           0.001430   1.752135  21:00:00   12-31-2015    21    0
# 4           0.001194   1.352436  00:00:00   01-01-2016     0    0
#
#   time_updated updated_timestamp  Unnamed: 0_y       timestamp_y  avg_rain  \
# 0        12:00  12-31-2015 12:00             4  12/31/2015 12:00       0.0
# ...

# %%
full_df = full_df.drop(['time_x','updated_date','hour','min','time_updated','timestamp_y','time_y','date'],axis=1)
full_df.head()
# Out:
#    airpressure     airtemp  specific_humidity  windspeed updated_timestamp  \
# 0   84055.0703  274.887909           0.000971   2.769442  12-31-2015 00:00
# 1   84247.2344  277.503204           0.001098   2.950434  12-31-2015 03:00
# 2   84256.8281  288.390137           0.001060   1.049703  12-31-2015 06:00
# 3   84185.4141  288.949371           0.001141   1.993747  12-31-2015 09:00
# 4   84141.4141  277.850464           0.001479   1.554527  12-31-2015 12:00
#
#    avg_rain
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       0.0

# %%
full_df.to_csv('refined_x_y.csv')

# %%
df_full = pd.read_csv('refined_x_y.csv')

df_full.head()
# Out:
#    Unnamed: 0  airpressure     airtemp  specific_humidity  windspeed  \
# 0           0   84055.0703  274.887909           0.000971   2.769442
# 1           1   84247.2344  277.503204           0.001098   2.950434
# 2           2   84256.8281  288.390137           0.001060   1.049703
# 3           3   84185.4141  288.949371           0.001141   1.993747
# 4           4   84141.4141  277.850464           0.001479   1.554527
#
#   updated_timestamp  avg_rain
# 0  12-31-2015 00:00       NaN
# 1  12-31-2015 03:00       NaN
# 2  12-31-2015 06:00       NaN
# 3  12-31-2015 09:00       NaN
# 4  12-31-2015 12:00       0.0

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13420 entries, 0 to 13419
# Data columns (total 7 columns):
# Unnamed: 0           13420 non-null int64
# airpressure          8776 non-null float64
# airtemp              8776 non-null float64
# specific_humidity    8776 non-null float64
# windspeed            8776 non-null float64
# updated_timestamp    13420 non-null object
# avg_rain             8776 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 734.0+ KB

# %%
df_full
df_full = df_full.drop('Unnamed: 0',axis=1)
df_full.head()
# Out:
#    airpressure     airtemp  specific_humidity  windspeed updated_timestamp  \
# 0   84055.0703  274.887909           0.000971   2.769442  12-31-2015 00:00
# 1   84247.2344  277.503204           0.001098   2.950434  12-31-2015 03:00
# 2   84256.8281  288.390137           0.001060   1.049703  12-31-2015 06:00
# 3   84185.4141  288.949371           0.001141   1.993747  12-31-2015 09:00
# 4   84141.4141  277.850464           0.001479   1.554527  12-31-2015 12:00
#
#    avg_rain
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       0.0

# %% [raw]
# After merging all the files, we have 4132 records for prediction
